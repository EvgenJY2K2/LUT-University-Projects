# %%
from urllib.request import urlopen
import requests
import json

def get_and_print_data(url):
    count = 0
    r = requests.get(url)
    info = r.json()
    
    for i in info["results"]:
            print("ID:{} - name:{} - type:{} species:{} - origin:{} - status:{}".format(i["id"], i["name"], i["type"], i["species"], i["origin"]["name"], i["status"]))
            count = count + 1
    return count

def get_url(url):
    r = requests.get(url)
    info = r.json()
    try:
        next_page = info["info"]["next"]
        url = get_url(next_page, page)
    except:
        None
        
    return next_page

def menu():
    print("You have the following options\n0) Exit\n1) Get all dead characters\n2) Get characters by their name and living status")
    action = int(input("Enter your selection:\n"))
    return action

def main():

    print("Welcome to Rick & Morty API")

    while True:
        oper = menu()
        
        if oper == 0:
            break

        elif oper == 1:
            lim = int(input("Enter limit of pages:\n"))
            
            print("Getting page 1 url: https://rickandmortyapi.com/api/character?status=dead")
            
            link = get_url("https://rickandmortyapi.com/api/character/?status=dead")
            
            list_of_links = []
            list_of_links.append("https://rickandmortyapi.com/api/character/?status=dead")
            
            for page in range(2, lim+1):
                print("Getting page {} url: {}".format(page, link))
                list_of_links.append(link)
                link = get_url(link)
            
            count_dead = 0
            for link in list_of_links:
                count = get_and_print_data(link)
                count_dead = count_dead + count
            
            print("Total number of {} dead characters".format(count_dead))

        elif oper == 2:
            char = input("Enter character to search for:\n")
            stat = input("Enter living status (alive, dead, unknown):\n")
            lim = int(input("Enter limit of pages:\n"))
            make_link =  "https://rickandmortyapi.com/api/character?name=" + char + "&status=" + stat
            
            print("Getting page 1 url:", make_link)
            
            link = get_url(make_link)
            
            list_of_links = []
            list_of_links.append(make_link)
            
            for page in range(2, lim+1):
                while link != None:
                    print("Getting page {} url: {}".format(page, link))
                    list_of_links.append(link)
                    link = get_url(link)
            
            count_char = 0
            for link in list_of_links:
                count = get_and_print_data(link)
                count_char = count_char + count
            
            print("Total number of {} {} {}'s found".format(count_char, stat, char))
            
            
main()
# Out:
# Welcome to Rick & Morty API
# You have the following options
# 0) Exit
# 1) Get all dead characters
# 2) Get characters by their name and living status
# Enter your selection:
# 1
# Enter limit of pages:
# 3
# Getting page 1 url: https://rickandmortyapi.com/api/character?status=dead
# Getting page 2 url: https://rickandmortyapi.com/api/character/?page=2&status=dead
# Getting page 3 url: https://rickandmortyapi.com/api/character/?page=3&status=dead
# ID:8 - name:Adjudicator Rick - type: species:Human - origin:unknown - status:Dead
# ID:9 - name:Agency Director - type: species:Human - origin:Earth (Replacement Dimension) - status:Dead
# ID:10 - name:Alan Rails - type:Superhuman (Ghost trains summoner) species:Human - origin:unknown - status:Dead
# ID:11 - name:Albert Einstein - type: species:Human - origin:Earth (C-137) - status:Dead
# ID:12 - name:Alexander - type: species:Human - origin:Earth (C-137) - status:Dead
# ID:16 - name:Amish Cyborg - type:Parasite species:Alien - origin:unknown - status:Dead
# ID:25 - name:Armothy - type:Self-aware arm species:unknown - origin:Post-Apocalyptic Earth - status:Dead
# ID:31 - name:Baby Wizard - type:Parasite species:Alien - origin:unknown - status:Dead
# ID:32 - name:Bearded Lady - type:Parasite species:Alien - origin:unknown - status:Dead
# ID:33 - name:Beebo - type: species:Alien - origin:Venzenulon 7 - status:Dead
# ID:40 - name:Beth's Mytholog - type:Mytholog species:Mythological Creature - origin:Nuptia 4 - status:Dead
# ID:43 - name:Big Morty - type: species:Human - origin:unknown - status:Dead
# ID:44 - name:Body Guard Morty - type: species:Human - origin:unknown - status:Dead
# ID:52 - name:Blue Footprint Guy - type: species:Human - origin:Post-Apocalyptic Earth - status:Dead
# ID:55 - name:Boobloosian - type:Boobloosian species:Alien - origin:unknown - status:Dead
# ID:56 - name:Bootleg Portal Chemist Rick - type: species:Human - origin:unknown - status:Dead
# ID:59 - name:Brad Anderson - type: species:Human - origin:Earth (Replacement Dimension) - status:Dead
# ID:60 - name:Calypso - type:Superhuman species:Human - origin:unknown - status:Dead
# ID:61 - name:Campaign Manager Morty - type: species:Human - origin:unknown - status:Dead
# ID:62 - name:Canklanker Thom - type:Gromflomite species:Alien - origin:Gromflom Prime - status:Dead
# ID:64 - name:Chris - type:Organic gun species:Alien - origin:unknown - status:Dead
# ID:66 - name:Coach Feratu (Balik Alistane) - type:Vampire species:Mythological Creature - origin:Earth (Replacement Dimension) - status:Dead
# ID:68 - name:Colossus - type: species:Human - origin:Post-Apocalyptic Earth - status:Dead
# ID:69 - name:Commander Rick - type: species:Human - origin:unknown - status:Dead
# ID:70 - name:Concerto - type: species:Humanoid - origin:unknown - status:Dead
# ID:71 - name:Conroy - type: species:Robot - origin:Earth (Replacement Dimension) - status:Dead
# ID:73 - name:Cop Morty - type: species:Human - origin:unknown - status:Dead
# ID:76 - name:Cousin Nicky - type:Parasite species:Alien - origin:unknown - status:Dead
# ID:81 - name:Crocubot - type:Robot-Crocodile hybrid species:Animal - origin:unknown - status:Dead
# ID:86 - name:Cyclops Rick - type: species:Humanoid - origin:unknown - status:Dead
# ID:87 - name:Cynthia - type:Zigerion species:Alien - origin:unknown - status:Dead
# ID:89 - name:Dale - type:Giant species:Mythological Creature - origin:Giant's Town - status:Dead
# ID:92 - name:Davin - type: species:Human - origin:Earth (C-137) - status:Dead
# ID:93 - name:Diablo Verde - type:Demon species:Mythological Creature - origin:unknown - status:Dead
# ID:94 - name:Diane Sanchez - type: species:Human - origin:Earth (C-137) - status:Dead
# ID:96 - name:Tuberculosis - type: species:Disease - origin:Anatomy Park - status:Dead
# ID:97 - name:Gonorrhea - type: species:Disease - origin:Anatomy Park - status:Dead
# ID:98 - name:Hepatitis A - type: species:Disease - origin:Anatomy Park - status:Dead
# ID:99 - name:Hepatitis C - type: species:Disease - origin:Anatomy Park - status:Dead
# ID:100 - name:Bubonic Plague - type: species:Disease - origin:Anatomy Park - status:Dead
# ID:101 - name:E. Coli - type: species:Disease - origin:Anatomy Park - status:Dead
# ID:102 - name:Donna Gueterman - type: species:Robot - origin:unknown - status:Dead
# ID:104 - name:Doom-Nomitron - type:Shapeshifter species:Alien - origin:unknown - status:Dead
# ID:105 - name:Dr. Glip-Glop - type: species:Alien - origin:unknown - status:Dead
# ID:108 - name:Dr. Xenon Bloom - type:Amoeba-Person species:Humanoid - origin:unknown - status:Dead
# ID:109 - name:Duck With Muscles - type:Parasite species:Alien - origin:unknown - status:Dead
# ID:116 - name:Evil Beth Clone - type:Clone species:Human - origin:unknown - status:Dead
# ID:117 - name:Evil Jerry Clone - type:Clone species:Human - origin:unknown - status:Dead
# ID:119 - name:Evil Rick - type:Robot species:Humanoid - origin:unknown - status:Dead
# ID:120 - name:Evil Summer Clone - type:Clone species:Human - origin:unknown - status:Dead
# ID:122 - name:Fart - type:Interdimensional gaseous being species:Alien - origin:unknown - status:Dead
# ID:127 - name:Frank Palicky - type: species:Human - origin:Earth (C-137) - status:Dead
# ID:128 - name:Frankenstein's Monster - type:Parasite species:Alien - origin:unknown - status:Dead
# ID:130 - name:Galactic Federation President - type:Gromflomite species:Alien - origin:unknown - status:Dead
# ID:131 - name:Gar Gloonch - type:Zombodian species:Alien - origin:unknown - status:Dead
# ID:132 - name:Gar's Mytholog - type:Mytholog species:Mythological Creature - origin:Nuptia 4 - status:Dead
# ID:135 - name:Garment District Rick - type: species:Human - origin:unknown - status:Dead
# ID:138 - name:General Nathan - type: species:Human - origin:Earth (Replacement Dimension) - status:Dead
# ID:139 - name:General Store Owner - type:Cat-Person species:Alien - origin:Purge Planet - status:Dead
# ID:141 - name:Ghost in a Jar - type:Parasite species:Alien - origin:unknown - status:Dead
# Total number of 60 dead characters
# You have the following options
# 0) Exit
# 1) Get all dead characters
# 2) Get characters by their name and living status
# Enter your selection:
# 2
# Enter character to search for:
# morty
# Enter living status (alive, dead, unknown):
# alive
# Enter limit of pages:
# 3
# Getting page 1 url: https://rickandmortyapi.com/api/character?name=morty&status=alive
# Getting page 2 url: https://rickandmortyapi.com/api/character?page=2&name=morty&status=alive
# ID:2 - name:Morty Smith - type: species:Human - origin:unknown - status:Alive
# ID:18 - name:Antenna Morty - type:Human with antennae species:Human - origin:unknown - status:Alive
# ID:27 - name:Artist Morty - type: species:Human - origin:unknown - status:Alive
# ID:77 - name:Cowboy Morty - type: species:Human - origin:unknown - status:Alive
# ID:84 - name:Cult Leader Morty - type: species:Human - origin:unknown - status:Alive
# ID:85 - name:Cyclops Morty - type: species:Humanoid - origin:unknown - status:Alive
# ID:118 - name:Evil Morty - type: species:Human - origin:unknown - status:Alive
# ID:123 - name:Fat Morty - type: species:Human - origin:unknown - status:Alive
# ID:143 - name:Glasses Morty - type: species:Human - origin:unknown - status:Alive
# ID:206 - name:Lizard Morty - type:Lizard-Person species:Humanoid - origin:unknown - status:Alive
# ID:229 - name:Morty Mart Manager Morty - type: species:Human - origin:unknown - status:Alive
# ID:230 - name:Morty Jr. - type:Human Gazorpian species:Humanoid - origin:Earth (Replacement Dimension) - status:Alive
# ID:232 - name:Morty Smith - type: species:Human - origin:Earth (Evil Rick's Target Dimension) - status:Alive
# ID:233 - name:Morty K-22 - type: species:Human - origin:Earth (K-22) - status:Alive
# ID:366 - name:Trunk Morty - type:Trunk-Person species:Humanoid - origin:Trunk World - status:Alive
# ID:392 - name:Bearded Morty - type: species:Human - origin:unknown - status:Alive
# ID:401 - name:Morty Jr's interviewer - type: species:Human - origin:Earth (Replacement Dimension) - status:Alive
# ID:473 - name:Bartender Morty - type: species:Human - origin:unknown - status:Alive
# ID:474 - name:Dancer Cowboy Morty - type: species:Human - origin:unknown - status:Alive
# ID:475 - name:Dancer Morty - type: species:Human - origin:unknown - status:Alive
# ID:476 - name:Flower Morty - type:Human with a flower in his head species:Human - origin:unknown - status:Alive
# ID:480 - name:Purple Morty - type: species:Alien - origin:unknown - status:Alive
# ID:505 - name:Fascist Shrimp Morty - type:Shrimp species:Animal - origin:Earth (Fascist Shrimp Dimension) - status:Alive
# ID:512 - name:Morty’s Lawyer - type: species:Human - origin:Earth (Replacement Dimension) - status:Alive
# ID:518 - name:Wasp Morty - type:Wasp species:Animal - origin:Earth (Wasp Dimension) - status:Alive
# ID:630 - name:Morty Smith - type:Soulless Puppet species:Human - origin:Story Train - status:Alive
# ID:636 - name:Evil Morty - type:Soulless Puppet species:Human - origin:Ricks’s Story - status:Alive
# ID:637 - name:Morty’s Disguise - type:Soulless Puppet species:Human - origin:Story Train - status:Alive
# ID:659 - name:Morty’s Father-in-law - type: species:Human - origin:Near-Duplicate Reality - status:Alive
# ID:660 - name:Morty’s Mother-in-law - type: species:Human - origin:Near-Duplicate Reality - status:Alive
# ID:661 - name:Morty’s Girlfriend - type: species:Human - origin:Near-Duplicate Reality - status:Alive
# ID:685 - name:Evolved Narnian Disguised as Morty - type:Narnian species:Humanoid - origin:Narnia Dimension - status:Alive
# ID:759 - name:Turkey Morty - type:Turkey species:Animal - origin:Earth (Replacement Dimension) - status:Alive
# ID:805 - name:Baby Mouse Skin Morty - type: species:Human - origin:Citadel of Ricks - status:Alive
# Total number of 34 alive morty's found
# You have the following options
# 0) Exit
# 1) Get all dead characters
# 2) Get characters by their name and living status
# Enter your selection:
# 0
